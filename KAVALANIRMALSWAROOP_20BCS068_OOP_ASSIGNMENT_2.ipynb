# %% [markdown]
# <a href="https://colab.research.google.com/github/NirmalSwaroopKavala/KAVALANIRMALSWAROOP_20BCS068_OOP-ASSIGNMENT-2/blob/main/KAVALANIRMALSWAROOP_20BCS068_OOP_ASSIGNMENT_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class circle():
  def __init__ (self,radius):
    self.radius = radius
  def area(self):
    return 3.14*(self.radius**2)
  def perimeter(self):
    return 2*3.14*self.radius

rad = int(input("Enter the radius of a circle : "))
c =circle(rad)
print(c.area())
print(c.perimeter())

name = []
emp_id = []
branch = []
salary = []
n = int(input("Enter number of elements in a list :"))
for i in range(0,n):
  fac_name = input("Enter name of faculty : ")
  fac_emp_id = input("Enter emp id : ")
  fac_branch = input("Enter the branch of the faculty : ")
  fac_salary = input("Enter salary of the faculty : ")
  name.append(fac_name)
  emp_id.append(fac_emp_id)
  branch.append(fac_branch)
  salary.append(fac_salary)

print("\nDetails of the" ,n ,"faculties are :")
for j in range(0,n):
  print(name[j],emp_id[j],branch[j],salary[j])

  class account:
  def _init_(self,Acc_no,Acc_holder_name,Amount):
    self.number = Acc_no
    self.name = Acc_holder_name
    self.amount = Amount
  def Deposit(self,Amount):
    self.amount += Amount
  def Withdraw(self,Amount):
    if Amount > self.amount:
      print("Insufficient balance")
      exit
    else:
      self.amount -= Amount
  def Checkbalance(self):
    print(self.amount)
  def Accountdetails(self):
    print("Account details are:")
    print(self.number,self.name,self.amount)
  
acc = account("140810","kundan",4300)
acc.Deposit(350)
acc.Withdraw(700)
acc.Checkbalance()
acc.Accountdetails()

def display():
  print(name,USN)
  for i in range(0,3):
    print(subjects[i] , "-" ,marks[i])

subjects = []
marks = []
name = input("Enter the name of the student : ")
USN = input("Enter USN of the student : ")
for j in range(0,3):
  subject  = input("Enter name of the subject : ")
  subjects.append(subject)
  mark = input("Enter the mark of the subject : ")
  marks.append(mark)

display()

class Patient:
  def _init_(self, name, admission_date, symptoms : list, oxygen_level, discharge_date):
    self.name = name
    self.admission_date = admission_date
    self.symptoms = symptoms
    self.oxygen_level = oxygen_level
    self.discharge_date = discharge_date

class Data:
  def _init_(self):
    self.oxygen_support = []
    self.general_ward = []

  def Patient(self, patient):
    if (patient.oxygen_level < 90):
      self.oxygen_support.append(patient)
    else:
      self.general_ward.append(patient)

  def numberOxygen(self):
    print(f"Totaal number of patients needing oxygen support is {len(self.oxygen_support)}")

  def numberGeneral(self):
    print(f"Total number of patients in general ward is {len(self.general_ward)}")

  def totalPatients(self):
    print(f"Total number of patients is {len(self.general_ward)+len(self.oxygen_support)}")

  def patientInfo(self):
    print("**Patients in oxygen support**")
    for patient in self.oxygen_support:
      print("\n")
      print("Name:", patient.name)
      print("Admission Date:", patient.admission_date)
      print("symptoms:", patient.symptoms)
      print("oxygen level:", patient.oxygen_level)
      print("Discharge Date:", patient.discharge_date)
      print("\n")

    print("**Patients in General ward**")
    for patient in self.general_ward:
      print("\n")
      print("Name:", patient.name)
      print("Admission Date:", patient.admission_date)
      print("symptoms:", patient.symptoms)
      print("oxygen level:", patient.oxygen_level)
      print("Discharge Date:", patient.discharge_date)
      print("\n")

patient1 = Patient("charan", "13/09/2021", ["Fever", "Body Pains"], 70, "14/09/2021")
patient2 = Patient("loki", "14/09/2021", ["Headache", "Fever"], 90, "17/09/2021")
patient3 = Patient("anil", "19/09/2021", ["Stomach Pain", "Loose Motion"], 120, "21/09/2021")
patient4 = Patient("prathamesh", "25/09/2021", ["Low Platelet Count", "Blood Vomiting"], 90, "30/09/2021")

db = Data()
db.Patient(patient1)
db.Patient(patient2)
db.Patient(patient3)
db.Patient(patient4)
db.patientInfo()
db.numberOxygen()
db.numberGeneral()
db.totalPatients()

class time():
  def _init_(self,hour,minutes,seconds):
    self.hour=hour
    self.minutes=minutes
    self.seconds=seconds
  def display(self):
    print(self.hour,":",self.minutes,":",self.seconds)
time1= time(10,30,15)
time1.display()

class students:
 std1=["Rahul",21,33]
 std2=["Roshit",22,74]

 def compare(self):
   if self.std1[2] == self.std2[2] :
    print("EQUAL")
   else :
    print("UNEQUAL")

obj=students()
obj.compare()

class Student:
    sem = 3
    institute = "IIIT Dharwad"
    
    def setData(self):
        self.name = input("Enter the name of the student : ")
        self.id = int(input("Enter the USN of student : "))

    def getInstanceData(self):
        print(f"Name : {self.name} \nUSN = {self.id}")

    @classmethod
    def getClassData(cls):
        print(f"Semester : {cls.sem} \nInstitute : {cls.institute} \n")

    @staticmethod
    def getExplanation():
        print("Class variables namely sem and institute are printed using ClassMethod and Instance variables namely name and id are printed using Instance Method")


s1 = Student()
s1.setData()
s1.getInstanceData()
Student.getClassData()
Student.getExplanation()

class student:
  def _init_(self,name,roll,sem):
    self.name=name
    self.roll=roll
    self.sem=sem
    self.lap=self.laptop()

  def show(self):
    print(self.name,self.roll,self.sem)
    self.lap.show()

  class laptop:
    def _init_(self):
      self.brand='DELL'
      self.cpu='i7'
      self.ram=16

    def show(self):
      print(self.brand,self.cpu,self.ram)

stud1=student('nirmalswaroop',68,3)

stud1.show()
